# %%
# Kernel Python (Pyodide)
#import and patch libraries for web use
import pyodide_http
pyodide_http.patch_all
import warnings
warnings.filterwarnings('ignore')

# packages with micropip
import micropip
await micropip.install("openpyxl")
await micropip.install("pandas")

#import pandas
import pandas as pd
#matplotlib library for plotting (I)
import matplotlib.pyplot as plt
#the statsmodels libraty for statistical modeling (II)
import statsmodels.api as sm

#install and import the seaborn library for data visualization
await micropip.install('seaborn')
import seaborn as sns

# file with data
excel_file = pd.ExcelFile("practice_scatter_plot_matrix.xlsx", engine='openpyxl')

data = pd.read_excel(excel_file)

#print the DataFrame to display the data
print(data)

print("Relationship between the Variables")

# Create scatterplots to visualize relationships between the variables
sns.pairplot(data[['Online_Ratings', 'Marketing_Spend', 'Social_Media_Engagement', 'Monthly_Sales']])
# Add a title to the scatterplot matrix
plt.suptitle('Scatter Plots of Independent Variables', y=1.02)

# Displat the Scatter plot matrix
plt.show()
# Out:
#    Month  Online_Ratings  Marketing_Spend  Social_Media_Engagement  \
# 0      1             4.5             2000                      500
# 1      2             4.7             2200                      520
# 2      3             4.6             2100                      510
# 3      4             4.8             2300                      550
# 4      5             4.9             2500                      570
# 5      6             4.5             2400                      560
# 6      7             4.6             2600                      590
# 7      8             4.7             2700                      600
# 8      9             4.8             2800                      620
# 9     10             4.9             2900                      630
#
#    Monthly_Sales
# 0          15000
# 1          15500
# 2          15200
# 3          16000
# 4          16500
# 5          16200
# 6          17000
# 7          17500
# 8          18000
# 9          18500
# Relationship between the Variables
